# %%
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Generate a set of 2,000 random latitudes and longitudes
lattitudes= np.random.uniform(low=-90.00, high=90.00, size=2000)
longitudes= np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_lngs= zip(lattitudes,longitudes)
coordinates = list(lat_lngs)

# %%
# retrieve the nearest city
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
 # perform an API call with the OpenWeatherMap
 # Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5216c9d077287ec4763264fa9b1e59f3

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 1 | the pas
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | gijon
# Processing Record 6 of Set 1 | kunashak
# Processing Record 7 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | broken hill
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | limon
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | mingshui
# Processing Record 14 of Set 1 | payo
# Processing Record 15 of Set 1 | wuxue
# Processing Record 16 of Set 1 | kavaratti
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | praya
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | campbell river
# Processing Record 21 of Set 1 | sinnamary
# Processing Record 22 of Set 1 | mayo
# Processing Record 23 of Set 1 | naron
# Processing Record 24 of Set 1 | charlestown
# Processing Record 25 of Set 1 | smithers
# Processing Record 26 of Set 1 | nipawin
# Processing Record 27 of Set 1 | hambantota
# Processing Record 28 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | san luis
# Processing Record 31 of Set 1 | tanout
# Processing Record 32 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 1 | fare
# Processing Record 34 of Set 1 | maarianhamina
# Processing Record 35 of Set 1 | puerto escondido
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | tuktoyaktuk
# Processing Record 41 of Set 1 | clinton
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | victoria
# Processing Record 44 of Set 1 | rio gallegos
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | laguna
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | quito
# Processing Record 50 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | oytal
# Processing Record 2 of Set 2 | bonthe
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | vera cruz
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | antalaha
# Processing Record 8 of Set 2 | taoudenni
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | aykhal
# Processing Record 13 of Set 2 | acapulco
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | coihaique
# Processing Record 18 of Set 2 | kamenka
# Processing Record 19 of Set 2 | fortuna
# Processing Record 20 of Set 2 | lumeje
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | belmonte
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | san patricio
# Processing Record 25 of Set 2 | bembereke
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | moundou
# Processing Record 31 of Set 2 | faanui
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | cayenne
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | biu
# Processing Record 36 of Set 2 | tual
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | cradock
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | jerome
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | cockburn town
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | saskylakh
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | constitucion
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | seoul
# Processing Record 3 of Set 3 | virginia beach
# Processing Record 4 of Set 3 | voi
# Processing Record 5 of Set 3 | araguacu
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | hobyo
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | bodden town
# Processing Record 12 of Set 3 | hovd
# Processing Record 13 of Set 3 | bam
# Processing Record 14 of Set 3 | porto nacional
# Processing Record 15 of Set 3 | aldan
# Processing Record 16 of Set 3 | leningradskiy
# Processing Record 17 of Set 3 | tromso
# Processing Record 18 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 3 | chuy
# Processing Record 20 of Set 3 | soni
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | cherskiy
# Processing Record 23 of Set 3 | aklavik
# Processing Record 24 of Set 3 | port lincoln
# Processing Record 25 of Set 3 | punta arenas
# Processing Record 26 of Set 3 | storslett
# Processing Record 27 of Set 3 | san cristobal
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | dicabisagan
# Processing Record 30 of Set 3 | buckeye
# Processing Record 31 of Set 3 | portland
# Processing Record 32 of Set 3 | kemijarvi
# Processing Record 33 of Set 3 | banda aceh
# Processing Record 34 of Set 3 | frumusita
# Processing Record 35 of Set 3 | tyukhtet
# Processing Record 36 of Set 3 | edd
# Processing Record 37 of Set 3 | riberalta
# Processing Record 38 of Set 3 | zhigansk
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | mantua
# Processing Record 41 of Set 3 | joshimath
# Processing Record 42 of Set 3 | lagoa
# Processing Record 43 of Set 3 | igarka
# Processing Record 44 of Set 3 | kamyaran
# Processing Record 45 of Set 3 | andra
# Processing Record 46 of Set 3 | jaciara
# Processing Record 47 of Set 3 | proletarskiy
# Processing Record 48 of Set 3 | paoua
# Processing Record 49 of Set 3 | kutum
# Processing Record 50 of Set 3 | betong
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | majene
# Processing Record 4 of Set 4 | caravelas
# Processing Record 5 of Set 4 | karratha
# Processing Record 6 of Set 4 | yerbogachen
# Processing Record 7 of Set 4 | vanimo
# Processing Record 8 of Set 4 | la asuncion
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | talisay
# Processing Record 11 of Set 4 | avera
# Processing Record 12 of Set 4 | sorland
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | itarema
# Processing Record 16 of Set 4 | sur
# Processing Record 17 of Set 4 | hofn
# Processing Record 18 of Set 4 | berlevag
# Processing Record 19 of Set 4 | inhambane
# Processing Record 20 of Set 4 | kupino
# Processing Record 21 of Set 4 | khatanga
# Processing Record 22 of Set 4 | salinopolis
# Processing Record 23 of Set 4 | pontes e lacerda
# Processing Record 24 of Set 4 | la spezia
# Processing Record 25 of Set 4 | dubbo
# Processing Record 26 of Set 4 | muros
# Processing Record 27 of Set 4 | naze
# Processing Record 28 of Set 4 | pacifica
# Processing Record 29 of Set 4 | isangel
# Processing Record 30 of Set 4 | lucapa
# Processing Record 31 of Set 4 | fegyvernek
# Processing Record 32 of Set 4 | kardymovo
# Processing Record 33 of Set 4 | chiautla
# Processing Record 34 of Set 4 | griffith
# Processing Record 35 of Set 4 | coquimbo
# Processing Record 36 of Set 4 | jardim
# Processing Record 37 of Set 4 | benguela
# Processing Record 38 of Set 4 | bud
# Processing Record 39 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 4 | jalu
# Processing Record 41 of Set 4 | dikson
# Processing Record 42 of Set 4 | makakilo city
# Processing Record 43 of Set 4 | ulaanbaatar
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | lorengau
# Processing Record 46 of Set 4 | itanagar
# Processing Record 47 of Set 4 | bathsheba
# Processing Record 48 of Set 4 | yulara
# Processing Record 49 of Set 4 | kiunga
# Processing Record 50 of Set 4 | esperance
# Processing Record 1 of Set 5 | killam
# Processing Record 2 of Set 5 | swedru
# Processing Record 3 of Set 5 | tasiilaq
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | poso
# Processing Record 6 of Set 5 | auki
# Processing Record 7 of Set 5 | kununurra
# Processing Record 8 of Set 5 | fairbanks
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | lixourion
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | songea
# Processing Record 13 of Set 5 | namibe
# Processing Record 14 of Set 5 | saint george
# Processing Record 15 of Set 5 | erenhot
# Processing Record 16 of Set 5 | amapa
# Processing Record 17 of Set 5 | huangchuan
# Processing Record 18 of Set 5 | biltine
# Processing Record 19 of Set 5 | salym
# Processing Record 20 of Set 5 | san ramon de la nueva oran
# Processing Record 21 of Set 5 | hay river
# Processing Record 22 of Set 5 | montalvo
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | ust-tsilma
# Processing Record 25 of Set 5 | mirandela
# Processing Record 26 of Set 5 | villeneuve-sur-lot
# Processing Record 27 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | abu dhabi
# Processing Record 30 of Set 5 | erdenet
# Processing Record 31 of Set 5 | wajid
# Processing Record 32 of Set 5 | misratah
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | broome
# Processing Record 35 of Set 5 | hamilton
# Processing Record 36 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 5 | ilam
# Processing Record 38 of Set 5 | lasa
# Processing Record 39 of Set 5 | acheng
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | nishihara
# Processing Record 42 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 5 | huarmey
# Processing Record 44 of Set 5 | airai
# Processing Record 45 of Set 5 | oksfjord
# Processing Record 46 of Set 5 | alice springs
# Processing Record 47 of Set 5 | shetpe
# Processing Record 48 of Set 5 | luganville
# Processing Record 49 of Set 5 | yankton
# Processing Record 50 of Set 5 | pervomayskoye
# Processing Record 1 of Set 6 | epe
# Processing Record 2 of Set 6 | lensk
# Processing Record 3 of Set 6 | surt
# Processing Record 4 of Set 6 | sanok
# Processing Record 5 of Set 6 | vostok
# Processing Record 6 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 6 | gimli
# Processing Record 8 of Set 6 | atasu
# Processing Record 9 of Set 6 | podporozhye
# Processing Record 10 of Set 6 | bilma
# Processing Record 11 of Set 6 | atambua
# Processing Record 12 of Set 6 | palana
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | berdigestyakh
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | voh
# Processing Record 19 of Set 6 | bumba
# Processing Record 20 of Set 6 | russkaya polyana
# Processing Record 21 of Set 6 | narasannapeta
# Processing Record 22 of Set 6 | ginir
# Processing Record 23 of Set 6 | castro
# Processing Record 24 of Set 6 | san luis obispo
# Processing Record 25 of Set 6 | vanavara
# Processing Record 26 of Set 6 | pisz
# Processing Record 27 of Set 6 | aguimes
# Processing Record 28 of Set 6 | cullman
# Processing Record 29 of Set 6 | marawi
# Processing Record 30 of Set 6 | malatya
# Processing Record 31 of Set 6 | cabo san lucas
# Processing Record 32 of Set 6 | flinders
# Processing Record 33 of Set 6 | pangnirtung
# Processing Record 34 of Set 6 | rizhao
# Processing Record 35 of Set 6 | maldonado
# Processing Record 36 of Set 6 | lubbock
# Processing Record 37 of Set 6 | inta
# Processing Record 38 of Set 6 | chapais
# Processing Record 39 of Set 6 | bataipora
# Processing Record 40 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 6 | mocajuba
# Processing Record 42 of Set 6 | mitzic
# Processing Record 43 of Set 6 | yellowknife
# Processing Record 44 of Set 6 | bayan
# Processing Record 45 of Set 6 | beian
# Processing Record 46 of Set 6 | vardo
# Processing Record 47 of Set 6 | iqaluit
# Processing Record 48 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 49 of Set 6 | tessalit
# Processing Record 50 of Set 6 | nhulunbuy
# Processing Record 1 of Set 7 | nago
# Processing Record 2 of Set 7 | serenje
# Processing Record 3 of Set 7 | novoagansk
# Processing Record 4 of Set 7 | tabory
# Processing Record 5 of Set 7 | udachnyy
# Processing Record 6 of Set 7 | nouadhibou
# Processing Record 7 of Set 7 | ambatofinandrahana
# Processing Record 8 of Set 7 | aripuana
# Processing Record 9 of Set 7 | prince rupert
# Processing Record 10 of Set 7 | cidreira
# Processing Record 11 of Set 7 | brae
# Processing Record 12 of Set 7 | charters towers
# Processing Record 13 of Set 7 | taltal
# Processing Record 14 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | namatanai
# Processing Record 16 of Set 7 | atkinson
# Processing Record 17 of Set 7 | yatou
# Processing Record 18 of Set 7 | sabla
# Processing Record 19 of Set 7 | vila velha
# Processing Record 20 of Set 7 | semnan
# Processing Record 21 of Set 7 | los llanos de aridane
# Processing Record 22 of Set 7 | lamar
# Processing Record 23 of Set 7 | mercedes
# Processing Record 24 of Set 7 | salalah
# Processing Record 25 of Set 7 | dwarka
# Processing Record 26 of Set 7 | anshun
# Processing Record 27 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 7 | hokitika
# Processing Record 29 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 7 | grand gaube
# Processing Record 32 of Set 7 | abu kamal
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | yenagoa
# Processing Record 35 of Set 7 | bethel
# Processing Record 36 of Set 7 | weyburn
# Processing Record 37 of Set 7 | scarisoara
# Processing Record 38 of Set 7 | luba
# Processing Record 39 of Set 7 | djambala
# Processing Record 40 of Set 7 | santa leopoldina
# Processing Record 41 of Set 7 | gravdal
# Processing Record 42 of Set 7 | ketchikan
# Processing Record 43 of Set 7 | campo verde
# Processing Record 44 of Set 7 | grindavik
# Processing Record 45 of Set 7 | tabou
# Processing Record 46 of Set 7 | trairi
# Processing Record 47 of Set 7 | havre-saint-pierre
# Processing Record 48 of Set 7 | rivadavia
# Processing Record 49 of Set 7 | marquette
# Processing Record 50 of Set 7 | langxiang
# Processing Record 1 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 8 | genc
# Processing Record 3 of Set 8 | athens
# Processing Record 4 of Set 8 | hualmay
# Processing Record 5 of Set 8 | magnor
# Processing Record 6 of Set 8 | nelson bay
# Processing Record 7 of Set 8 | bereda
# Processing Record 8 of Set 8 | fortuna foothills
# Processing Record 9 of Set 8 | tazovskiy
# Processing Record 10 of Set 8 | cerro largo
# Processing Record 11 of Set 8 | narsaq
# Processing Record 12 of Set 8 | storforshei
# Processing Record 13 of Set 8 | egvekinot
# Processing Record 14 of Set 8 | asau
# Processing Record 15 of Set 8 | morshansk
# Processing Record 16 of Set 8 | zholymbet
# Processing Record 17 of Set 8 | jumla
# Processing Record 18 of Set 8 | pacocha
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | dera din panah
# City not found. Skipping...
# Processing Record 21 of Set 8 | belen
# Processing Record 22 of Set 8 | ginda
# Processing Record 23 of Set 8 | beira
# Processing Record 24 of Set 8 | spalding
# Processing Record 25 of Set 8 | harper
# Processing Record 26 of Set 8 | puerto quijarro
# Processing Record 27 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 8 | pacasmayo
# Processing Record 29 of Set 8 | kalangala
# Processing Record 30 of Set 8 | luwuk
# Processing Record 31 of Set 8 | pulaski
# Processing Record 32 of Set 8 | weiser
# Processing Record 33 of Set 8 | ormara
# Processing Record 34 of Set 8 | deputatskiy
# Processing Record 35 of Set 8 | nowy sacz
# Processing Record 36 of Set 8 | santa maria
# Processing Record 37 of Set 8 | touros
# Processing Record 38 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 39 of Set 8 | lompoc
# Processing Record 40 of Set 8 | hinton
# Processing Record 41 of Set 8 | gorom-gorom
# Processing Record 42 of Set 8 | morondava
# Processing Record 43 of Set 8 | tondano
# Processing Record 44 of Set 8 | bat yam
# Processing Record 45 of Set 8 | yuxia
# Processing Record 46 of Set 8 | mariel
# Processing Record 47 of Set 8 | phan thiet
# Processing Record 48 of Set 8 | klaksvik
# Processing Record 49 of Set 8 | tommot
# Processing Record 50 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | smirnykh
# Processing Record 3 of Set 9 | abrau-dyurso
# Processing Record 4 of Set 9 | krasnyy yar
# Processing Record 5 of Set 9 | timra
# Processing Record 6 of Set 9 | raga
# Processing Record 7 of Set 9 | luderitz
# Processing Record 8 of Set 9 | pingliang
# Processing Record 9 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 9 | kharp
# Processing Record 11 of Set 9 | mpika
# Processing Record 12 of Set 9 | kahului
# Processing Record 13 of Set 9 | lavrentiya
# Processing Record 14 of Set 9 | mackay
# Processing Record 15 of Set 9 | ilulissat
# Processing Record 16 of Set 9 | emmett
# Processing Record 17 of Set 9 | linapacan
# City not found. Skipping...
# Processing Record 18 of Set 9 | haicheng
# Processing Record 19 of Set 9 | bengkulu
# Processing Record 20 of Set 9 | fredericksburg
# Processing Record 21 of Set 9 | yunyang
# Processing Record 22 of Set 9 | east london
# Processing Record 23 of Set 9 | atbasar
# Processing Record 24 of Set 9 | sangre grande
# Processing Record 25 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 26 of Set 9 | khorramshahr
# Processing Record 27 of Set 9 | san francisco
# Processing Record 28 of Set 9 | okhotsk
# Processing Record 29 of Set 9 | merrill
# Processing Record 30 of Set 9 | saint-pierre
# Processing Record 31 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 9 | kodiak
# Processing Record 33 of Set 9 | den helder
# Processing Record 34 of Set 9 | luau
# Processing Record 35 of Set 9 | sao joao da barra
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | odesskoye
# Processing Record 38 of Set 9 | la sarre
# Processing Record 39 of Set 9 | svetlyy
# Processing Record 40 of Set 9 | san jose
# Processing Record 41 of Set 9 | berdyuzhye
# City not found. Skipping...
# Processing Record 42 of Set 9 | la romana
# Processing Record 43 of Set 9 | cartagena
# Processing Record 44 of Set 9 | bezhanitsy
# Processing Record 45 of Set 9 | west wendover
# Processing Record 46 of Set 9 | seydi
# Processing Record 47 of Set 9 | evensk
# Processing Record 48 of Set 9 | kruisfontein
# Processing Record 49 of Set 9 | manzanillo
# Processing Record 50 of Set 9 | beloha
# Processing Record 1 of Set 10 | mokhsogollokh
# Processing Record 2 of Set 10 | pisco
# Processing Record 3 of Set 10 | porto novo
# Processing Record 4 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 5 of Set 10 | ekhabi
# Processing Record 6 of Set 10 | tomatlan
# Processing Record 7 of Set 10 | atar
# Processing Record 8 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 10 | mabaruma
# Processing Record 10 of Set 10 | deder
# Processing Record 11 of Set 10 | conakry
# Processing Record 12 of Set 10 | dingle
# Processing Record 13 of Set 10 | waingapu
# Processing Record 14 of Set 10 | ingraj bazar
# Processing Record 15 of Set 10 | buraydah
# Processing Record 16 of Set 10 | antofagasta
# Processing Record 17 of Set 10 | san miguel
# Processing Record 18 of Set 10 | clyde river
# Processing Record 19 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 10 | ahipara
# Processing Record 21 of Set 10 | walvis bay
# Processing Record 22 of Set 10 | orbetello
# Processing Record 23 of Set 10 | samarai
# Processing Record 24 of Set 10 | goldap
# Processing Record 25 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 10 | te anau
# Processing Record 27 of Set 10 | carora
# Processing Record 28 of Set 10 | portobelo
# Processing Record 29 of Set 10 | pitimbu
# Processing Record 30 of Set 10 | alakurtti
# Processing Record 31 of Set 10 | rocha
# Processing Record 32 of Set 10 | sobolevo
# Processing Record 33 of Set 10 | lere
# Processing Record 34 of Set 10 | port hardy
# Processing Record 35 of Set 10 | baherden
# Processing Record 36 of Set 10 | caernarfon
# Processing Record 37 of Set 10 | goderich
# Processing Record 38 of Set 10 | adrar
# Processing Record 39 of Set 10 | alihe
# Processing Record 40 of Set 10 | half moon bay
# Processing Record 41 of Set 10 | pontypool
# Processing Record 42 of Set 10 | baoqing
# Processing Record 43 of Set 10 | valdivia
# Processing Record 44 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 10 | hopewell
# Processing Record 46 of Set 10 | teguldet
# Processing Record 47 of Set 10 | correntina
# Processing Record 48 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 10 | gladstone
# Processing Record 50 of Set 10 | chara
# Processing Record 1 of Set 11 | belaya gora
# Processing Record 2 of Set 11 | praia da vitoria
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | rosendal
# Processing Record 5 of Set 11 | sept-iles
# Processing Record 6 of Set 11 | northam
# Processing Record 7 of Set 11 | raudeberg
# Processing Record 8 of Set 11 | opuwo
# Processing Record 9 of Set 11 | massakory
# Processing Record 10 of Set 11 | ola
# Processing Record 11 of Set 11 | lyuban
# Processing Record 12 of Set 11 | nanga eboko
# Processing Record 13 of Set 11 | kungurtug
# Processing Record 14 of Set 11 | toungoo
# City not found. Skipping...
# Processing Record 15 of Set 11 | longyearbyen
# Processing Record 16 of Set 11 | yei
# Processing Record 17 of Set 11 | alyangula
# Processing Record 18 of Set 11 | baisha
# Processing Record 19 of Set 11 | manasa
# Processing Record 20 of Set 11 | ngaoundere
# Processing Record 21 of Set 11 | nguruka
# Processing Record 22 of Set 11 | ambon
# Processing Record 23 of Set 11 | mandal
# Processing Record 24 of Set 11 | mecca
# Processing Record 25 of Set 11 | great yarmouth
# Processing Record 26 of Set 11 | tarakan
# Processing Record 27 of Set 11 | san juan
# Processing Record 28 of Set 11 | buala
# Processing Record 29 of Set 11 | saquena
# Processing Record 30 of Set 11 | lima
# Processing Record 31 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 11 | canyon
# Processing Record 33 of Set 11 | bodo
# Processing Record 34 of Set 11 | matamoros
# Processing Record 35 of Set 11 | kirakira
# Processing Record 36 of Set 11 | coswig
# Processing Record 37 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 11 | benjamin hill
# Processing Record 39 of Set 11 | gat
# Processing Record 40 of Set 11 | boende
# Processing Record 41 of Set 11 | choix
# Processing Record 42 of Set 11 | yinchuan
# Processing Record 43 of Set 11 | moissala
# Processing Record 44 of Set 11 | plettenberg bay
# Processing Record 45 of Set 11 | tamandare
# Processing Record 46 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 47 of Set 11 | lebowakgomo
# Processing Record 48 of Set 11 | naifaru
# Processing Record 49 of Set 11 | orcopampa
# Processing Record 50 of Set 11 | punta alta
# Processing Record 1 of Set 12 | dunedin
# Processing Record 2 of Set 12 | huanren
# Processing Record 3 of Set 12 | akdepe
# Processing Record 4 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 5 of Set 12 | kem
# Processing Record 6 of Set 12 | kaeo
# Processing Record 7 of Set 12 | tucumcari
# Processing Record 8 of Set 12 | kapit
# Processing Record 9 of Set 12 | muisne
# Processing Record 10 of Set 12 | constancia
# Processing Record 11 of Set 12 | alofi
# Processing Record 12 of Set 12 | luyang
# Processing Record 13 of Set 12 | birjand
# Processing Record 14 of Set 12 | harrogate
# Processing Record 15 of Set 12 | alpena
# Processing Record 16 of Set 12 | poum
# Processing Record 17 of Set 12 | mandera
# Processing Record 18 of Set 12 | unye
# City not found. Skipping...
# Processing Record 19 of Set 12 | bukene
# Processing Record 20 of Set 12 | solone
# Processing Record 21 of Set 12 | katghora
# Processing Record 22 of Set 12 | saurimo
# Processing Record 23 of Set 12 | thinadhoo
# Processing Record 24 of Set 12 | guayaramerin
# Processing Record 25 of Set 12 | awbari
# Processing Record 26 of Set 12 | tecoanapa
# Processing Record 27 of Set 12 | belomorsk
# Processing Record 28 of Set 12 | alugan
# Processing Record 29 of Set 12 | kaabong
# Processing Record 30 of Set 12 | oktyabrskiy
# Processing Record 31 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 12 | baruun-urt
# Processing Record 33 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 12 | muli
# Processing Record 35 of Set 12 | macherla
# Processing Record 36 of Set 12 | yumen
# Processing Record 37 of Set 12 | pacific grove
# Processing Record 38 of Set 12 | olga
# Processing Record 39 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 41 of Set 12 | olafsvik
# Processing Record 42 of Set 12 | santa fe
# Processing Record 43 of Set 12 | evanston
# Processing Record 44 of Set 12 | port hedland
# Processing Record 45 of Set 12 | houma
# Processing Record 46 of Set 12 | icanti
# City not found. Skipping...
# Processing Record 47 of Set 12 | kaoma
# Processing Record 48 of Set 12 | paamiut
# Processing Record 49 of Set 12 | hampton
# Processing Record 50 of Set 12 | sabzevar
# Processing Record 1 of Set 13 | necochea
# Processing Record 2 of Set 13 | mogadishu
# Processing Record 3 of Set 13 | gisborne
# Processing Record 4 of Set 13 | hefei
# Processing Record 5 of Set 13 | tenno
# Processing Record 6 of Set 13 | yashkul
# Processing Record 7 of Set 13 | laguna de perlas
# Processing Record 8 of Set 13 | elbistan
# Processing Record 9 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 10 of Set 13 | tambura
# Processing Record 11 of Set 13 | otane
# Processing Record 12 of Set 13 | balkanabat
# Processing Record 13 of Set 13 | kozhva
# Processing Record 14 of Set 13 | lota
# Processing Record 15 of Set 13 | henties bay
# Processing Record 16 of Set 13 | fredericton
# Processing Record 17 of Set 13 | vadso
# Processing Record 18 of Set 13 | aswan
# Processing Record 19 of Set 13 | kuliyapitiya
# Processing Record 20 of Set 13 | denpasar
# Processing Record 21 of Set 13 | launceston
# Processing Record 22 of Set 13 | natal
# Processing Record 23 of Set 13 | nanortalik
# Processing Record 24 of Set 13 | alice town
# Processing Record 25 of Set 13 | ust-kan
# Processing Record 26 of Set 13 | tilichiki
# Processing Record 27 of Set 13 | nkhotakota
# Processing Record 28 of Set 13 | marsh harbour
# Processing Record 29 of Set 13 | thaton
# Processing Record 30 of Set 13 | ixtapa
# Processing Record 31 of Set 13 | sabha
# Processing Record 32 of Set 13 | yangjiang
# Processing Record 33 of Set 13 | kharitonovo
# Processing Record 34 of Set 13 | maine-soroa
# Processing Record 35 of Set 13 | juneau
# Processing Record 36 of Set 13 | porbandar
# Processing Record 37 of Set 13 | doka
# Processing Record 38 of Set 13 | chicama
# Processing Record 39 of Set 13 | grants
# Processing Record 40 of Set 13 | lesosibirsk
# Processing Record 41 of Set 13 | bay roberts
# Processing Record 42 of Set 13 | ambato
# Processing Record 43 of Set 13 | marbella
# Processing Record 44 of Set 13 | boralday
# Processing Record 45 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 13 | cavan
# Processing Record 47 of Set 13 | tanah merah
# Processing Record 48 of Set 13 | matata
# Processing Record 49 of Set 13 | unai
# Processing Record 50 of Set 13 | maneadero
# Processing Record 1 of Set 14 | gadwal
# Processing Record 2 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 3 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 14 | cuxhaven
# Processing Record 5 of Set 14 | miri
# Processing Record 6 of Set 14 | sao gabriel da cachoeira
# Processing Record 7 of Set 14 | amboasary
# Processing Record 8 of Set 14 | nadadores
# Processing Record 9 of Set 14 | oussouye
# Processing Record 10 of Set 14 | opobo
# City not found. Skipping...
# Processing Record 11 of Set 14 | yanam
# Processing Record 12 of Set 14 | inongo
# Processing Record 13 of Set 14 | esperanza
# Processing Record 14 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 14 | beringovskiy
# Processing Record 16 of Set 14 | bijie
# Processing Record 17 of Set 14 | verkhoyansk
# Processing Record 18 of Set 14 | maralal
# Processing Record 19 of Set 14 | tezu
# Processing Record 20 of Set 14 | dakar
# Processing Record 21 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 14 | kuala terengganu
# Processing Record 23 of Set 14 | mangrol
# Processing Record 24 of Set 14 | mitchell
# Processing Record 25 of Set 14 | acajutla
# Processing Record 26 of Set 14 | teahupoo
# Processing Record 27 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 14 | anadyr
# Processing Record 29 of Set 14 | wajir
# Processing Record 30 of Set 14 | aktau
# Processing Record 31 of Set 14 | bossier city
# Processing Record 32 of Set 14 | tonantins
# Processing Record 33 of Set 14 | ahuimanu
# Processing Record 34 of Set 14 | ponta delgada
# Processing Record 35 of Set 14 | biak
# Processing Record 36 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 37 of Set 14 | malinyi
# Processing Record 38 of Set 14 | faya
# Processing Record 39 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 14 | razdolnoye
# Processing Record 41 of Set 14 | bose
# Processing Record 42 of Set 14 | olinda
# Processing Record 43 of Set 14 | sioux lookout
# Processing Record 44 of Set 14 | boulder city
# Processing Record 45 of Set 14 | mwinilunga
# Processing Record 46 of Set 14 | lafiagi
# Processing Record 47 of Set 14 | mamallapuram
# Processing Record 48 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 14 | doctor arroyo
# Processing Record 50 of Set 14 | san quintin
# Processing Record 1 of Set 15 | bahia de caraquez
# Processing Record 2 of Set 15 | sayyan
# Processing Record 3 of Set 15 | eureka
# Processing Record 4 of Set 15 | la rioja
# Processing Record 5 of Set 15 | la argentina
# Processing Record 6 of Set 15 | magdagachi
# Processing Record 7 of Set 15 | agadez
# Processing Record 8 of Set 15 | knysna
# Processing Record 9 of Set 15 | bowen
# Processing Record 10 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 11 of Set 15 | sibolga
# Processing Record 12 of Set 15 | azare
# Processing Record 13 of Set 15 | cabo rojo
# Processing Record 14 of Set 15 | bereznik
# Processing Record 15 of Set 15 | teya
# Processing Record 16 of Set 15 | aljezur
# Processing Record 17 of Set 15 | champerico
# Processing Record 18 of Set 15 | masterton
# Processing Record 19 of Set 15 | srednekolymsk
# Processing Record 20 of Set 15 | fallingbostel
# Processing Record 21 of Set 15 | callaway
# Processing Record 22 of Set 15 | zeya
# Processing Record 23 of Set 15 | yarada
# Processing Record 24 of Set 15 | solnechnyy
# Processing Record 25 of Set 15 | nynashamn
# Processing Record 26 of Set 15 | tokonou
# Processing Record 27 of Set 15 | rupert
# Processing Record 28 of Set 15 | kawai
# Processing Record 29 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 15 | prescott
# Processing Record 31 of Set 15 | cabedelo
# Processing Record 32 of Set 15 | sulangan
# Processing Record 33 of Set 15 | arlit
# Processing Record 34 of Set 15 | estelle
# Processing Record 35 of Set 15 | seversk
# Processing Record 36 of Set 15 | bandarbeyla
# Processing Record 37 of Set 15 | romitan
# Processing Record 38 of Set 15 | jiuquan
# Processing Record 39 of Set 15 | dolores
# Processing Record 40 of Set 15 | isiro
# Processing Record 41 of Set 15 | samfya
# Processing Record 42 of Set 15 | puerto carreno
# Processing Record 43 of Set 15 | methoni
# Processing Record 44 of Set 15 | ust-nera
# Processing Record 45 of Set 15 | linjiang
# Processing Record 46 of Set 15 | sibenik
# Processing Record 47 of Set 15 | muana
# Processing Record 48 of Set 15 | chimichagua
# Processing Record 49 of Set 15 | borgarnes
# Processing Record 50 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 16 | fiche
# Processing Record 2 of Set 16 | niceville
# Processing Record 3 of Set 16 | nalut
# Processing Record 4 of Set 16 | okandja
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Add the weather data to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hilo  19.7297 -155.0900     68.00        88          90
# 1        The Pas  53.8251 -101.2541     30.20        80          90
# 2        Ushuaia -54.8000  -68.3000     46.40        61          40
# 3          Gijon  43.5357   -5.6615     57.00        87           0
# 4       Kunashak  55.7032   61.5498     30.20        59           0
# ..           ...      ...       ...       ...       ...         ...
# 683  Chimichagua   9.2578  -73.8123     99.90        28          99
# 684    Borgarnes  64.5383  -21.9206     30.99        82         100
# 685        Fiche   9.8000   38.7333     55.71        40         100
# 686    Niceville  30.5169  -86.4822     82.40        78          75
# 687        Nalut  30.3333   10.8500     65.89        17          87
#
#      Wind Speed Country                 Date
# 0          6.91      US  2021-03-28 19:47:03
# 1         21.85      CA  2021-03-28 19:47:04
# 2         25.32      AR  2021-03-28 19:47:04
# 3          3.00      ES  2021-03-28 19:47:04
# 4         15.66      RU  2021-03-28 19:47:05
# ..          ...     ...                  ...
# 683        3.27      CO  2021-03-28 19:49:50
# 684        8.99      IS  2021-03-28 19:49:50
# 685        4.76      ET  2021-03-28 19:49:50
# 686       12.66      US  2021-03-28 19:49:50
# 687       10.74      LY  2021-03-28 19:49:51
#
# [688 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Date","Lat","Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed" ]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0           Hilo      US  2021-03-28 19:47:03  19.7297 -155.0900     68.00
# 1        The Pas      CA  2021-03-28 19:47:04  53.8251 -101.2541     30.20
# 2        Ushuaia      AR  2021-03-28 19:47:04 -54.8000  -68.3000     46.40
# 3          Gijon      ES  2021-03-28 19:47:04  43.5357   -5.6615     57.00
# 4       Kunashak      RU  2021-03-28 19:47:05  55.7032   61.5498     30.20
# ..           ...     ...                  ...      ...       ...       ...
# 683  Chimichagua      CO  2021-03-28 19:49:50   9.2578  -73.8123     99.90
# 684    Borgarnes      IS  2021-03-28 19:49:50  64.5383  -21.9206     30.99
# 685        Fiche      ET  2021-03-28 19:49:50   9.8000   38.7333     55.71
# 686    Niceville      US  2021-03-28 19:49:50  30.5169  -86.4822     82.40
# 687        Nalut      LY  2021-03-28 19:49:51  30.3333   10.8500     65.89
#
#      Humidity  Cloudiness  Wind Speed
# 0          88          90        6.91
# 1          80          90       21.85
# 2          61          40       25.32
# 3          87           0        3.00
# 4          59           0       15.66
# ..        ...         ...         ...
# 683        28          99        3.27
# 684        82         100        8.99
# 685        40         100        4.76
# 686        78          75       12.66
# 687        17          87       10.74
#
# [688 rows x 9 columns]

# %%
# Export the DataFrame to a CSV file
# Create the output file (CSV).
output_data_file = "weather_data/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
